# %%
import numpy as np
import matplotlib.pyplot as plt
import os
join = os.path.join
from tqdm import tqdm
from skimage import transform 
from torch.utils.data import Dataset, DataLoader
import torch.multiprocessing as mp
import sys
sys.path.append('./modified_medsam_repo')
import random
from datetime import datetime
import pandas as pd
import nibabel as nib
import pickle

# %%
pd.read_pickle('/gpfs/data/luilab/karthik/pediatric_seg_proj/subset_train_id_dfs_pooled/repeat_experiments/1/repeat0.pkl')
# Out:
# {'train': array([901442]),
#  'val': [151425,
#   214221,
#   453441,
#   146735,
#   147737,
#   555954,
#   214524,
#   134324,
#   531536,
#   173435,
#   196952,
#   193239,
#   197449,
#   249947,
#   116524,
#   138837,
#   211720,
#   626648,
#   598568,
#   304727,
#   911849,
#   513736,
#   943862,
#   111312,
#   193845,
#   729557,
#   111009,
#   922854,
#   227533,
#   168745,
#   112819,
#   108121,
#   137229,
#   704238,
#   199352,
#   463040,
#   123723,
#   615744,
#   387959,
#   329440,
#   176037,
#   142424,
#   114217,
#   106016,
#   835657,
#   135730,
#   115320,
#   581349,
#   111514,
#   128329,
#   281135,
#   994273,
#   220721,
#   599671,
#   172938,
#   173536,
#   825553,
#   154532,
#   160830,
#   870861,
#   919966,
#   200614,
#   852455,
#   102109,
#   212419,
#   429040,
#   175035,
#   820745,
#   112516,
#   969476,
#   297655,
#   627852,
#   120010,
#   518746,
#   145632,
#   185038,
#   199251,
#   165840,
#   611938,
#   395251,
#   555348,
#   123824,
#   342129,
#   161731,
#   136631,
#   158136,
#   432332,
#   189349,
#   144226,
#   379657,
#   680957,
#   300618,
#   680452,
#   613538,
#   623137,
#   209228,
#   529549,
#   151526,
#   137431,
#   205119,
#   121416,
#   107321,
#   151829,
#   668361,
#   588565,
#   199453,
#   130720,
#   148840,
#   415837,
#   151930,
#   763557],
#  'test': [162935,
#   979984,
#   200008,
#   211922,
#   989987,
#   779370,
#   108525,
#   187850,
#   351938,
#   955465,
#   173940,
#   119833,
#   692964,
#   102513,
#   251833,
#   693764,
#   103414,
#   510225,
#   973770,
#   729254,
#   782561,
#   569965,
#   728454,
#   171330,
#   113922,
#   156536,
#   169040,
#   255740,
#   132118,
#   580650,
#   102008,
#   525541,
#   156031,
#   148032,
#   112112,
#   789373,
#   765056,
#   751550,
#   104820,
#   204521,
#   130518,
#   573249,
#   130922,
#   761957,
#   210415,
#   609143,
#   952863,
#   148941,
#   160931,
#   519647,
#   283543,
#   112920,
#   349244,
#   786569,
#   346137,
#   517239,
#   368753,
#   905147,
#   224022,
#   201717,
#   144933,
#   151021,
#   214625,
#   157437,
#   576255,
#   308129,
#   257946,
#   366042,
#   166640,
#   788876,
#   627549,
#   256540,
#   645450,
#   849264,
#   492754,
#   102311,
#   182032,
#   305830,
#   173839,
#   110613,
#   580044,
#   194847,
#   210617,
#   154936,
#   680250,
#   856968,
#   599469,
#   155635,
#   102614,
#   106521,
#   117122,
#   127832,
#   198855,
#   898176,
#   120111,
#   204218,
#   877168,
#   123117,
#   107220,
#   561242,
#   727553,
#   127630,
#   201818,
#   481951,
#   110411,
#   558960,
#   211821,
#   178243,
#   745555,
#   365343,
#   152427]}
