# %%
# Notebook to create df for each label (e.g. label1_only_df.csv) which contains slices with at least one of that label
# (plus a random selection of other slices)
# will compare these in the training process

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
join = os.path.join
from tqdm import tqdm
from skimage import transform 
from torch.utils.data import Dataset, DataLoader
import torch.multiprocessing as mp
import sys
sys.path.append('./modified_medsam_repo')
sys.path.append('../../modified_medsam_repo')
import random
from datetime import datetime
import pandas as pd
import nibabel as nib
import pickle   
from MedSAM_HCP.dataset import LabelConverter
from glob import glob

# %%
total_df = pd.read_csv('/gpfs/data/luilab/karthik/pediatric_seg_proj/path_df_constant_bbox.csv')
df_hcp = pd.read_csv('/gpfs/home/kn2347/HCP_MedSAM_project/modified_medsam_repo/hcp_mapping_processed.csv')
df_desired = pd.read_csv('/gpfs/home/kn2347/HCP_MedSAM_project/modified_medsam_repo/darts_name_class_mapping_processed.csv')
label_converter = LabelConverter(df_hcp, df_desired)

# %%
frac_blanks_to_include = 0.1 # i.e. 10%

collector = {}
for i, r in tqdm(total_df.iterrows(), total=total_df.shape[0]):
    #print(i)
    seg_path = r['segmentation_slice_path']
    arr = np.load(seg_path)
    arr = label_converter.hcp_to_compressed(arr)
    unq_vals = set(arr.flatten())
    for j in unq_vals:
        if j not in collector:
            collector[j] = []
        #print(f'adding to {j}')
        collector[j].append(i)
# Out:
# 100%|██████████| 284928/284928 [2:41:41<00:00, 29.37it/s]

# %%
len(collector[1])
# Out:
# 121003

# %%
np.random.seed(2024)
total_indices = set(range(total_df.shape[0]))

frac_list = [0.1]
for frac_blanks_to_include in frac_list:
    for label_num in range(1, 103):
        # take set difference to get unincluded slices in this
        unused_idxs = list(total_indices - set(collector[label_num]))
        

        # now choose a random fraction of them
        chosen_idxs = np.random.choice(a = unused_idxs, size = round(frac_blanks_to_include * len(unused_idxs)), replace=False).tolist()

        idxs_for_label = collector[label_num] + chosen_idxs
        idxs_for_label.sort()
        label_df = total_df.iloc[idxs_for_label, :].reset_index(drop=True)

        targ_dir = f'/gpfs/data/luilab/karthik/pediatric_seg_proj/per_class_isolated_df_new/{label_num}/{frac_blanks_to_include}'
        if not os.path.exists(targ_dir):
            os.makedirs(targ_dir)
        label_df.to_csv(f'{targ_dir}/isolated_path_df_constant_bbox.csv', index=False)

        unet_version = label_df[['id', 'slice', 'image_path', 'segmentation_slice_path']]
        unet_version = unet_version.rename({'image_path': 'img_slice_path'}, axis=1)
        unet_version.to_csv(f'{targ_dir}/isolated_path_df_unet.csv', index=False)

# %%
# Out:
#            id  slice                         image_embedding_slice_path  \
# 0      100206    152  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 1      100206    153  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 2      100206    154  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 3      100206    155  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 4      100206    156  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# ...       ...    ...                                                ...
# 48349  996782    191  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 48350  996782    192  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 48351  996782    193  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 48352  996782    194  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 48353  996782    195  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
#
#                                  segmentation_slice_path  \
# 0      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 1      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 2      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 3      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 4      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# ...                                                  ...
# 48349  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 48350  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 48351  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 48352  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 48353  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
#
#                                               image_path  bbox_0  bbox_1  \
# 0      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 1      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 2      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 3      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 4      /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# ...                                                  ...     ...     ...
# 48349  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 48350  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 48351  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 48352  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 48353  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
#
#        bbox_2  bbox_3
# 0         256     256
# 1         256     256
# 2         256     256
# 3         256     256
# 4         256     256
# ...       ...     ...
# 48349     256     256
# 48350     256     256
# 48351     256     256
# 48352     256     256
# 48353     256     256
#
# [48354 rows x 9 columns]

# %%
yu = glob('/gpfs/data/luilab/karthik/pediatric_seg_proj/per_class_isolated_df_new/5/*/isolated_path_df_unet.csv')
for jj in yu:
    print(jj.split('/')[-2])
    print(pd.read_csv(jj).shape[0])
    print('===')
# Out:
# 0.05
# 78906
# ===
# 0.01
# 70232
# ===
# 0.001
# 68280
# ===
# 0.25
# 122279
# ===
# 1
# 284928
# ===
# 0.1
# 89749
# ===
# 0
# 68063
# ===

# %%
# Out:
#             id  slice                         image_embedding_slice_path  \
# 0       100206      0  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 1       100206      1  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 2       100206      2  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 3       100206      3  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 4       100206      4  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# ...        ...    ...                                                ...
# 284923  996782    251  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 284924  996782    252  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 284925  996782    253  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 284926  996782    254  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
# 284927  996782    255  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/pr...
#
#                                   segmentation_slice_path  \
# 0       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 1       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 2       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 3       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 4       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# ...                                                   ...
# 284923  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 284924  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 284925  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 284926  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
# 284927  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/se...
#
#                                                image_path  bbox_0  bbox_1  \
# 0       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 1       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 2       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 3       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 4       /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# ...                                                   ...     ...     ...
# 284923  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 284924  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 284925  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 284926  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
# 284927  /gpfs/data/cbi/hcp/hcp_ya/hcp_ya_slices_npy/di...       0       0
#
#         bbox_2  bbox_3
# 0          256     256
# 1          256     256
# 2          256     256
# 3          256     256
# 4          256     256
# ...        ...     ...
# 284923     256     256
# 284924     256     256
# 284925     256     256
# 284926     256     256
# 284927     256     256
#
# [284928 rows x 9 columns]

# %%
medsam_df = pd.read_csv('/gpfs/data/luilab/karthik/pediatric_seg_proj/path_df_constant_bbox.csv')
class_counts

merged = medsam_df.merge(class_counts, how='left', on=['id', 'slice'])

# %%
for label in range(1, 103):
    key = f'label{label}'
    zz = merged[key].to_numpy()
    xx = (merged[key] >= np.quantile(zz[zz > 0], 0.05)) | (merged[key] ==0)
    savepath = f'/gpfs/data/luilab/karthik/pediatric_seg_proj/per_class_eval_dfs/quantile5_mask_arrays/label{label}.npy'
    np.save(savepath, xx)

for label in range(1, 103):
    key = f'label{label}'
    zz = merged[key].to_numpy()
    xx = (merged[key] >= 100) | (merged[key] == 0)
    savepath = f'/gpfs/data/luilab/karthik/pediatric_seg_proj/per_class_eval_dfs/at_least_100_mask_arrays/label{label}.npy'
    np.save(savepath, xx)

# %%
xx.sum() * 0.1/64
# Out:
# 435.75156250000003

# %%
### Df's for classes with >= x pixels
class_counts = pd.read_csv('/gpfs/data/luilab/karthik/pediatric_seg_proj/class_counts/class_counts_per_slice.csv')
dicto = {}
for i, r in class_counts.iterrows():
    for label in [1,5,7]:
        dicto[(r['id'], r['slice'], label)] = r[f'label{label}']


#class_counts = class_counts[(class_counts['label1'] >= 69) | (class_counts['label1'] == 0)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 for i, r in class_counts.iterrows():
#       5     for label in [1,5,7]:
# ----> 6         dicto[(r['id'], r['slice'], label)] = r[f'label{label}']
#
# File ~/.conda/envs/medsam/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.conda/envs/medsam/lib/python3.10/site-packages/pandas/core/series.py:1090, in Series._get_value(self, label, takeable)
#    1088 # Similar to Index.get_value, but we do not fall back to positional
#    1089 loc = self.index.get_loc(label)
# -> 1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/.conda/envs/medsam/lib/python3.10/site-packages/pandas/core/indexes/base.py:5944, in Index._get_values_for_loc(self, series, loc, key)
#    5935 """
#    5936 Do a positional lookup on the given Series, returning either a scalar
#    5937 or a Series.
#    (...)
#    5941 key is included for MultiIndex compat.
#    5942 """
#    5943 if is_integer(loc):
# -> 5944     return series._values[loc]
#    5946 return series.iloc[loc]
#
# File ~/.conda/envs/medsam/lib/python3.10/site-packages/pandas/core/series.py:740, in Series._values(self)
#     708 @property
#     709 def _values(self):
#     710     """
#     711     Return the internal repr of this data (defined by Block.interval_values).
#     712     This are the values as stored in the Block (ndarray or ExtensionArray
#    (...)
#     738
#     739     """
# --> 740     return self._mgr.internal_values()
#
# KeyboardInterrupt:

# %%
cutoffs = {}
for lab in range(1, 103):
    xy = class_counts[f'label{lab}']
    xy = xy[xy>0]
    cutoffs[lab] = np.quantile(xy, 0.05)

print(cutoffs[7])
# using:
# label 1: 66
# label 5: 20
# label 7: 11
# Out:
# 11.0

# %%
def operate(pathname, label, cutoff, suffix_name):
    df = pd.read_csv(pathname)
    mask = [] 
    for i, r in df.iterrows():
        tup = (r['id'], r['slice'], label)
        cnts = dicto[tup]
        mask.append(cnts >= cutoff or cnts == 0)

    df = df[mask].reset_index(drop=True)

    rt = f'/gpfs/data/luilab/karthik/pediatric_seg_proj/per_class_eval_dfs/{label}'
    if not os.path.exists(rt):
        os.makedirs(rt)

    prefix = pathname.split('/')[-1].split('.csv')[0]
    suffix = suffix_name
    
    to_path = f'{rt}/{prefix}{suffix}.csv'
    df.to_csv(to_path, index=False)
    return to_path

for label in [1,5,7]:
    # threshold by 0.05th quantile
    operate('/gpfs/data/luilab/karthik/pediatric_seg_proj/path_df_constant_bbox.csv', label, cutoffs[label], '_filter_bottom_5%')
    operate('/gpfs/data/luilab/karthik/pediatric_seg_proj/path_df_unet.csv', label, cutoffs[label], '_filter_bottom_5%')

    # threshold by 100 pixels
    operate('/gpfs/data/luilab/karthik/pediatric_seg_proj/path_df_constant_bbox.csv', label, 100, '_filter_under_100')
    operate('/gpfs/data/luilab/karthik/pediatric_seg_proj/path_df_unet.csv', label, 100, '_filter_under_100')

# %%
class_counts
# Out:
#             id  slice  label1  label2  label3  label4  label5  label6  label7  \
# 81      100206     81     146       0       0       0       0       0       0
# 82      100206     82     212       0       0       0       0       0       0
# 83      100206     83     292       0       0       0       0       0       0
# 84      100206     84     352       0       0       0       0       0       0
# 85      100206     85     412       0       0       0       0       0       0
# ...        ...    ...     ...     ...     ...     ...     ...     ...     ...
# 284851  989987    179     278       0       0     643    1347       0       0
# 284852  989987    180     233       0       0     756    1267       0       0
# 284853  989987    181     179       0       0     906    1092       0       0
# 284854  989987    182     132       0       0     814    1118       0       0
# 284855  989987    183      89       0       0     685    1174       0       0
#
#         label8  ...  label93  label94  label95  label96  label97  label98  \
# 81           0  ...      197       20        0        0      278       40
# 82           0  ...      233       28        0        0      285       38
# 83           0  ...      267       36        0        0      301       96
# 84           0  ...      279       46        0        0      351      143
# 85           0  ...      333       50        0        0      393      186
# ...        ...  ...      ...      ...      ...      ...      ...      ...
# 284851       0  ...        0        0        0        0        0        0
# 284852       0  ...        0        0        0        0        0        0
# 284853       0  ...        0        0        0        0        0        0
# 284854       0  ...        0        0        0        0        0        0
# 284855       0  ...        0        0        0        0        0        0
#
#         label99  label100  label101  label102
# 81            0         0         0         0
# 82            0         0         0         0
# 83            0         0         0         0
# 84            0         0         0         0
# 85            0         0         0         0
# ...         ...       ...       ...       ...
# 284851        0         0         0         0
# 284852        0         0         0         0
# 284853        0         0         0         0
# 284854        0         0         0         0
# 284855        0         0         0         0
#
# [114734 rows x 104 columns]
